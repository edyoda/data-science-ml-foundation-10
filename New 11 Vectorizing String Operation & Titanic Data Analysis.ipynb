# %%
import pandas as pd

# %%
goal_data = pd.read_csv('goal_stats_euro_leagues_2012-13.csv')

# %%
goal_data['NewState'] = goal_data.Stat.str.count('a')

# %%
goal_data['l'] = goal_data.Stat.str.len()

# %%
goal_data
# Out:
#          Month           Stat    EPL  La Liga  Serie A  Bundesliga  NewState  \
# 0   08/01/2012  MatchesPlayed   20.0       20     10.0        10.0         2
# 1   09/01/2012  MatchesPlayed   38.0       39     50.0        44.0         2
# 2   10/01/2012  MatchesPlayed   31.0       31     39.0        27.0         2
# 3   11/01/2012  MatchesPlayed   50.0       41     42.0        46.0         2
# 4   12/01/2012  MatchesPlayed   59.0       39     39.0        26.0         2
# 5   01/01/2013  MatchesPlayed   42.0       40     40.0        18.0         2
# 6   02/01/2013  MatchesPlayed   30.0       40     40.0        36.0         2
# 7   03/01/2013  MatchesPlayed   35.0       38     39.0        36.0         2
# 8   04/01/2013  MatchesPlayed   42.0       42     41.0        36.0         2
# 9   05/01/2013  MatchesPlayed   33.0       40     40.0        27.0         2
# 10  06/02/2013  MatchesPlayed    NaN       10      NaN         NaN         2
# ...

# %%
import pandas as pd
titanic_data = pd.read_csv('titanic-train.csv',index_col='PassengerId')

# %%
titanic_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic_data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 123.5+ KB

# %%
### Show which col have how manu null entries

# %%
titanic_data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#delete all the rows of Cabin column
titanic_data.drop("Cabin",axis=1,inplace=True)

# %%
titanic_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500        S
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# ...

# %%
o = titanic_data.groupby('Sex').size()

# %%
o
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
titanic_data.groupby('Sex').describe()
# Out:
#           Age                                                       Fare  \
#         count       mean        std   min   25%   50%   75%   max  count
# Sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0  314.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0  577.0
#
#                   ...  SibSp      Survived                                     \
#              mean ...    75%  max    count      mean       std  min  25%  50%
# Sex               ...
# female  44.479818 ...    1.0  8.0    314.0  0.742038  0.438211  0.0  0.0  1.0
# male    25.523893 ...    0.0  8.0    577.0  0.188908  0.391775  0.0  0.0  0.0
#
#
#         75%  max
# Sex
# female  1.0  1.0
# male    0.0  1.0
#
# [2 rows x 48 columns]

# %%
titanic_data[titanic_data.Fare > 500]
# Out:
#              Survived  Pclass                                Name     Sex  \
# PassengerId
# 259                 1       1                    Ward, Miss. Anna  female
# 680                 1       1  Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1              Lesurer, Mr. Gustave J    male
#
#               Age  SibSp  Parch    Ticket      Fare Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.3292        C
# 680          36.0      0      1  PC 17755  512.3292        C
# 738          35.0      0      0  PC 17755  512.3292        C

# %%
titanic_data['Fare'].argmax()
# Out:
# 259

# %%
titanic_data.loc[titanic_data['Fare'].idxmax()]
# Out:
# Survived                   1
# Pclass                     1
# Name        Ward, Miss. Anna
# Sex                   female
# Age                       35
# SibSp                      0
# Parch                      0
# Ticket              PC 17755
# Fare                 512.329
# Embarked                   C
# Name: 259, dtype: object

# %%
titanic_data[titanic_data.Fare == titanic_data.Fare.max()]
# Out:
#              Survived  Pclass                                Name     Sex  \
# PassengerId
# 259                 1       1                    Ward, Miss. Anna  female
# 680                 1       1  Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1              Lesurer, Mr. Gustave J    male
#
#               Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.3292          NaN        C
# 680          36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 738          35.0      0      0  PC 17755  512.3292         B101        C

# %%
titanic_data['name_length'] = titanic_data.Name.str.len()

# %%
titanic_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
titanic_data[titanic_data['name_length'] == titanic_data.name_length.max()]
# Out:
#              Survived  Pclass  \
# PassengerId
# 308                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 308          Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0
#
#              SibSp  Parch    Ticket   Fare Embarked  name_length
# PassengerId
# 308              1      0  PC 17758  108.9        C           82

# %%
#Finding all not null age rows & assign to new dataframe age_titanic_data
age_titanic_data = titanic_data[pd.notnull(titanic_data['Age'])]

# %%
age_titanic_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
#Making age column as index
age_titanic_data.set_index('Age',inplace=True)

# %%
def getAgeCat(age):
    if age <= 18:
        return 'Kid'
    else:
        return 'Adult'
    
age_titanic_data.groupby(getAgeCat).size()
# Out:
# Adult    575
# Kid      139
# dtype: int64

# %%
age_titanic_data.groupby(lambda age: 'Kid' if age <= 18 else 'Adult').size()
# Out:
# Adult    575
# Kid      139
# dtype: int64

# %%
def f(age):
    
    if age < 18:
        return "Kid"
    elif age > 18:
        return "Adult"
    else:
        return "Not Known"
    
titanic_data['Status'] = titanic_data.Age.map(f)

# %%
titanic_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
titanic_data.Name.str.len()
# Out:
# PassengerId
# 1      23
# 2      51
# 3      22
# 4      44
# 5      24
# 6      16
# 7      23
# 8      30
# 9      49
# 10     35
# 11     31
# 12     24
# 13     30
# 14     27
# 15     36
# 16     32
# 17     20
# 18     28
# 19     55
# 20     23
# 21     20
# 22     21
# 23     27
# 24     28
# 25     29
# 26     57
# 27     23
# 28     30
# 29     29
# 30     19
#        ..
# 862    27
# 863    51
# 864    33
# 865    22
# 866    24
# 867    28
# 868    36
# 869    27
# 870    31
# 871    17
# 872    48
# 873    24
# 874    27
# 875    37
# 876    32
# 877    29
# 878    20
# 879    18
# 880    45
# 881    44
# 882    18
# 883    28
# 884    29
# 885    22
# 886    36
# 887    21
# 888    28
# 889    40
# 890    21
# 891    19
# Name: Name, Length: 891, dtype: int64

# %%
titanic_data.dropna()
titanic_data.Name.str.split(' ')
# Out:
# PassengerId
# 1                           [Braund,, Mr., Owen, Harris]
# 2      [Cumings,, Mrs., John, Bradley, (Florence, Bri...
# 3                             [Heikkinen,, Miss., Laina]
# 4      [Futrelle,, Mrs., Jacques, Heath, (Lily, May, ...
# 5                          [Allen,, Mr., William, Henry]
# 6                                   [Moran,, Mr., James]
# 7                           [McCarthy,, Mr., Timothy, J]
# 8                    [Palsson,, Master., Gosta, Leonard]
# 9      [Johnson,, Mrs., Oscar, W, (Elisabeth, Vilhelm...
# 10             [Nasser,, Mrs., Nicholas, (Adele, Achem)]
# 11                  [Sandstrom,, Miss., Marguerite, Rut]
# 12                          [Bonnell,, Miss., Elizabeth]
# 13                   [Saundercock,, Mr., William, Henry]
# 14                      [Andersson,, Mr., Anders, Johan]
# 15            [Vestrom,, Miss., Hulda, Amanda, Adolfina]
# 16               [Hewlett,, Mrs., (Mary, D, Kingcome), ]
# ...

# %%
sum(titanic_data.Name.str.len() == 0)
# Out:
# 0

# %%
#Convert name into list of strings
titanic_data['fullname'] =titanic_data.Name.str.split(",")

# %%
#Getting the first word from the list
titanic_data['firstname'] = titanic_data.fullname.map(lambda s : s[0])

# %%
titanic_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
titanic_data['fullname'] =titanic_data.Name.str.split(",",n=1,expand=True)

# %%
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
titanic_data['firstname'] = titanic_data.Name.map(lambda s : s[0])

# %%
titanic_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('abc.jpg')

# %%
img.shape
# Out:
# (385, 363, 3)

# %%
titanic_data['listname']  = titanic_data.Name.str.split(',')

# %%
# Out:
# PassengerId
# 1                             [ Mr. Owen Harris, Braund]
# 2      [ Mrs. John Bradley (Florence Briggs Thayer), ...
# 3                              [ Miss. Laina, Heikkinen]
# 4        [ Mrs. Jacques Heath (Lily May Peel), Futrelle]
# 5                            [ Mr. William Henry, Allen]
# 6                                    [ Mr. James, Moran]
# 7                             [ Mr. Timothy J, McCarthy]
# 8                      [ Master. Gosta Leonard, Palsson]
# 9      [ Mrs. Oscar W (Elisabeth Vilhelmina Berg), Jo...
# 10                [ Mrs. Nicholas (Adele Achem), Nasser]
# 11                    [ Miss. Marguerite Rut, Sandstrom]
# 12                           [ Miss. Elizabeth, Bonnell]
# 13                     [ Mr. William Henry, Saundercock]
# 14                        [ Mr. Anders Johan, Andersson]
# 15               [ Miss. Hulda Amanda Adolfina, Vestrom]
# 16                   [ Mrs. (Mary D Kingcome) , Hewlett]
# ...

# %%
review = pd.read_csv('Reviews.csv')

# %%
review.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
review.Text.str.split(" ").map(lambda l: sorted(l)).map(lambda l: l[-1])
# Out:
# 0                to
# 1              were
# 2             yummy
# 3               you
# 4             yummy
# 5             would
# 6           wrapped
# 7               you
# 8              with
# 9              very
# 10             your
# 11            where
# 12           years.
# 13             were
# 14           yummy.
# 15              you
# 16              zip
# 17             with
# 18         weighted
# 19              was
# 20             well
# 21            worth
# 22              you
# 23           weight
# 24              yrs
# 25         received
# 26            would
# 27              was
# 28              you
# 29             your
#             ...
# 568424          you
# 568425          you
# 568426         your
# 568427         with
# 568428        would
# 568429         with
# 568430          was
# 568431        worth
# 568432        would
# 568433          you
# 568434     wouldn't
# 568435        would
# 568436        would
# 568437          you
# ...

# %%
review.Text.map(lambda string : string.startswith('a') or string.startswith('b'))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 568424    False
# 568425    False
# 568426    False
# 568427    False
# 568428    False
# 568429    False
# 568430    False
# 568431    False
# 568432    False
# 568433    False
# 568434    False
# 568435    False
# 568436    False
# 568437    False
# 568438    False
# 568439    False
# 568440    False
# 568441    False
# 568442    False
# 568443    False
# 568444    False
# 568445    False
# 568446    False
# 568447    False
# ...

# %%
import re

# %%
re.match(r'[a-m]\w+',"aj@gmail.com")
# Out:
# <_sre.SRE_Match object; span=(0, 2), match='aj'>

# %%
re.match(r'[a-m]\w+',"zbc")

# %%
def chk(string):
    if re.match(r'[a-m]\w+',string):
        return True
    else:
        return False

# %%
review[review.Text.map(lambda string : chk(string))]
# Out:
#             Id   ProductId          UserId                        ProfileName  \
# 13          14  B001GVISJM  A18ECVX2RJ7HUE                    willie "roadie"
# 248        249  B007TFONH0  A3ICO2ROSXHIPM                           tightwad
# 285        286  B000H13270  A1YLOZQKBX3J1S         R. Lee Dailey "Lee_Dailey"
# 477        478  B000G6RYNE  A2LS9RBSI8SDZF                        Ashish Shah
# 538        539  B000G6RYNE  A2NI99G9BANORP                       cgoldsmith19
# 623        624  B000G6RYNE   AKGQ6RM68SQY1              Catherine Diane "CDI"
# 759        760  B0035YE9CS  A1Z1RVRG9CFCB7                           taostalk
# 824        825  B003AO5DLO  A1DYP6HZQ3AGZU                             hnryan
# 847        848  B0041CKRJC   A4MPDQF63WAEO                            vintage
# 958        959  B000S806VM   AL4M4T6T3JHY3                        candiceemoe
# 994        995  B006F2NYI2  A1T5CH6SHV989P                          a biemold
# ...

# %%
review.Summary.map(lambda string : chk(string))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-38f90ce53db2> in <module>()
# ----> 1 review.Summary.map(lambda string : chk(string))
#
# ~\Anaconda3-N\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas\_libs\src\inference.pyx in pandas._libs.lib.map_infer (pandas\_libs\lib.c:66645)()
#
# <ipython-input-78-38f90ce53db2> in <lambda>(string)
# ----> 1 review.Summary.map(lambda string : chk(string))
#
# <ipython-input-72-e6584ed5f4e7> in chk(string)
#       1 def chk(string):
# ----> 2     if re.match(r'[a-m]\w+',string):
#       3         return True
#       4     else:
#       5         return False
#
# ...

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
# Id                        568454 non-null int64
# ProductId                 568454 non-null object
# UserId                    568454 non-null object
# ProfileName               568438 non-null object
# HelpfulnessNumerator      568454 non-null int64
# HelpfulnessDenominator    568454 non-null int64
# Score                     568454 non-null int64
# Time                      568454 non-null int64
# Summary                   568428 non-null object
# Text                      568454 non-null object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
review_cl = review[review.Summary.notnull()]

# %%
review_cl[review_cl.Summary.map(lambda string : chk(string))]
# Out:
#             Id   ProductId          UserId  \
# 13          14  B001GVISJM  A18ECVX2RJ7HUE
# 37          38  B001EO5QW8  A3MGP2E1ZZ6GRB
# 46          47  B001EO5QW8   AQLL2R1PPR46X
# 59          60  B004N5KULM  A2QOGOXPOVKAJG
# 64          65  B005DUM9UQ  A2XIHNXODNZGV4
# 106        107  B004K2IHUO  A1ZKFQLHFZAEH9
# 134        135  B003OB0IB8  A1D0URD0AL237J
# 149        150  B0037ZFEW4   ABTKZKAWOK4DC
# 191        192  B004V6AH34  A3POAWC2JPQQQP
# 206        207  B0028C44Z0   A5F7YR0G7H9HR
# 209        210  B0009XLVGA  A3S84SEN2Z6DZU
# 232        233  B003ZFXJDW  A2HL6876LDPJIM
# 248        249  B007TFONH0  A3ICO2ROSXHIPM
# 249        250  B000GGKQSO  A1OE23J37ZPDXE
# 260        261  B002MV23XM  A2M6O8YORUA8PW
# 273        274  B000LKZK7C  A2582KMXLK2P06
# 284        285  B000H13270  A3J6I70Z9Q0HRX
# 306        307  B003EMU7EU  A3DSWITPB6NBT5
# 322        323  B000JEHAHS  A2MMFEZ728S1MA
# 325        326  B003VTN95K   A6Y49ZNS6NPN0
# 329        330  B003VTN95K  A3GLQSR6MTHXGL
# ...
