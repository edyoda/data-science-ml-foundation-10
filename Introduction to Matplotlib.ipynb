# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)

# %%
fig = plt.figure()

# %%
a = plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %%
x
# Out:
# array([  0.        ,   0.1010101 ,   0.2020202 ,   0.3030303 ,
#          0.4040404 ,   0.50505051,   0.60606061,   0.70707071,
#          0.80808081,   0.90909091,   1.01010101,   1.11111111,
#          1.21212121,   1.31313131,   1.41414141,   1.51515152,
#          1.61616162,   1.71717172,   1.81818182,   1.91919192,
#          2.02020202,   2.12121212,   2.22222222,   2.32323232,
#          2.42424242,   2.52525253,   2.62626263,   2.72727273,
#          2.82828283,   2.92929293,   3.03030303,   3.13131313,
#          3.23232323,   3.33333333,   3.43434343,   3.53535354,
#          3.63636364,   3.73737374,   3.83838384,   3.93939394,
#          4.04040404,   4.14141414,   4.24242424,   4.34343434,
#          4.44444444,   4.54545455,   4.64646465,   4.74747475,
#          4.84848485,   4.94949495,   5.05050505,   5.15151515,
#          5.25252525,   5.35353535,   5.45454545,   5.55555556,
#          5.65656566,   5.75757576,   5.85858586,   5.95959596,
# ...

# %%
fig.savefig('a.png')

# %%
a[0]

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))

# %% [markdown]
# ### Simple Line Plots

# %%
plt.plot(x, np.sin(x), color='#FF0000')

# %%
plt.plot(x, np.sin(x), color=(1.0,0.2,0.3))

# %%
plt.plot(x, np.sin(x), ':r')

# %%
plt.plot(x,np.sin(x), label='sin(x)')
plt.plot(x,np.cos(x), label='cos(x)')
plt.xlim(-1,15)
plt.ylim(-1.5, 1.5)
plt.xlabel('Info')
plt.ylabel('Cool')
plt.title('A Sine Curve')

plt.legend()

# %% [markdown]
# ### Simple Scatter Plots

# %%
x = np.linspace(0,10,30)
y = np.sin(x)

plt.plot(x,y, 'o', color='black')

# %%
plt.plot(x,y, '<', color='black')

# %%
plt.plot(x,y, '-o')

# %%
rng = np.random.RandomState(0)

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
#rng = np.random.RandomState(0)
y = rng.randn(100)
colors = rng.rand(100)

# %%
rng

# %%
sizes = 1000 * rng.rand(100)

# %%
plt.scatter(x,y, c=colors,s=sizes, alpha=0.3, cmap='inferno')
plt.colorbar()

# %% [markdown]
# * Doesn't matter for smaller datasets
# * plot has limited functionality & thus faster
# * scatter has more functionaility & thus slower'

# %% [markdown]
# ### Contour

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

# %%
X,Y = np.meshgrid(x,y)

# %%
Z = f(X,Y)

# %%
plt.contourf(X,Y,Z,20,cmap='RdGy')
plt.colorbar()

# %% [markdown]
# ### Histograms, Binning

# %%
data = np.random.normal(0,1,1000)

# %%
plt.hist(data,alpha=.3, bins=30)
# Out:
# (array([   1.,    3.,    1.,   10.,    9.,   11.,   16.,   24.,   31.,
#           64.,   60.,   76.,   94.,   93.,   85.,  102.,   62.,   64.,
#           60.,   38.,   33.,   26.,   12.,   11.,    7.,    2.,    2.,
#            0.,    2.,    1.]),
#  array([-3.0971556 , -2.87430183, -2.65144806, -2.42859429, -2.20574052,
#         -1.98288674, -1.76003297, -1.5371792 , -1.31432543, -1.09147166,
#         -0.86861789, -0.64576411, -0.42291034, -0.20005657,  0.0227972 ,
#          0.24565097,  0.46850475,  0.69135852,  0.91421229,  1.13706606,
#          1.35991983,  1.5827736 ,  1.80562738,  2.02848115,  2.25133492,
#          2.47418869,  2.69704246,  2.91989624,  3.14275001,  3.36560378,
#          3.58845755]),
#  <a list of 30 Patch objects>)
