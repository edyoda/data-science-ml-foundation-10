# %% [markdown]
# ### Grouping of Data

# %%
import pandas as pd

# %%
football_data = pd.read_csv('soccerdata-master\data\cl_13_14.csv')

# %%
football_data.size
# Out:
# 1200

# %%
football_data.head()
# Out:
#                 home  homescore  awayscore                 away  \
# 0  Borussia Dortmund          1          2  Zenit St Petersburg
# 1  Manchester United          3          0           Olympiakos
# 2            Chelsea          2          0          Galatasaray
# 3        Real Madrid          3          1           Schalke 04
# 4          Barcelona          2          1      Manchester City
#
#                         date                                group
# 0  Wednesday, March 19, 2014  UEFA CHAMPIONS LEAGUE - ROUND OF 16
# 1  Wednesday, March 19, 2014  UEFA CHAMPIONS LEAGUE - ROUND OF 16
# 2    Tuesday, March 18, 2014  UEFA CHAMPIONS LEAGUE - ROUND OF 16
# 3    Tuesday, March 18, 2014  UEFA CHAMPIONS LEAGUE - ROUND OF 16
# 4  Wednesday, March 12, 2014  UEFA CHAMPIONS LEAGUE - ROUND OF 16

# %%
footballgb = football_data.groupby('home')

# %%
footballgb.groups
# Out:
# {'AC Milan': Int64Index([12, 23, 78, 102, 113], dtype='int64'),
#  'Ajax Amsterdam': Int64Index([46, 54, 94], dtype='int64'),
#  'Anderlecht': Int64Index([36, 68, 84], dtype='int64'),
#  'Apoel Nicosia': Int64Index([147], dtype='int64'),
#  'Arsenal': Int64Index([13, 42, 74, 90, 117], dtype='int64'),
#  'Atletico Madrid': Int64Index([6, 21, 53, 100], dtype='int64'),
#  'Austria Vienna': Int64Index([22, 76, 101, 118, 153], dtype='int64'),
#  'BATE Borisov': Int64Index([189], dtype='int64'),
#  'Barcelona': Int64Index([4, 24, 55, 103], dtype='int64'),
#  'Bayer Leverkusen': Int64Index([14, 32, 64, 80], dtype='int64'),
#  'Bayern Munich': Int64Index([7, 30, 71, 110], dtype='int64'),
#  'Benfica': Int64Index([28, 69, 108], dtype='int64'),
#  'Birkirkara': Int64Index([193], dtype='int64'),
#  'Borussia Dortmund': Int64Index([0, 43, 50, 91], dtype='int64'),
#  'CS Fola Esch': Int64Index([194], dtype='int64'),
#  'CSKA Moscow': Int64Index([38, 70, 86], dtype='int64'),
# ...

# %%
footballgb.size()
# Out:
# home
# AC Milan                5
# Ajax Amsterdam          3
# Anderlecht              3
# Apoel Nicosia           1
# Arsenal                 5
# Atletico Madrid         4
# Austria Vienna          5
# BATE Borisov            1
# Barcelona               4
# Bayer Leverkusen        4
# Bayern Munich           4
# Benfica                 3
# Birkirkara              1
# Borussia Dortmund       4
# CS Fola Esch            1
# CSKA Moscow             3
# Celtic                  6
# Chelsea                 4
# Cliftonville            1
# Dinamo Tbilisi          2
# Dinamo Zagreb           3
# EB Streymur             2
# Elfsborg                2
# FC Basel                5
# FC Copenhagen           3
# FC Daugava              1
# FC Metalist Kharkiv     1
# FC Nordsjaelland        1
# FC Porto                3
# FH Hafnarfjordur        2
#                        ..
# NK Maribor              3
# Napoli                  3
# Neftchi                 1
# Nomme Kalju             2
# ...

# %%
groupedstatsdf = pd.read_csv('goal_stats_euro_leagues_2012-13.csv')

# %%
groupedstatsdf.head(3)
# Out:
#         Month           Stat   EPL  La Liga  Serie A  Bundesliga
# 0  08/01/2012  MatchesPlayed  20.0       20     10.0        10.0
# 1  09/01/2012  MatchesPlayed  38.0       39     50.0        44.0
# 2  10/01/2012  MatchesPlayed  31.0       31     39.0        27.0

# %%
groupedstatsdf.tail(3)
# Out:
#          Month         Stat    EPL  La Liga  Serie A  Bundesliga
# 19  04/01/2013  GoalsScored  105.0      127    102.0       104.0
# 20  05/01/2013  GoalsScored   96.0      109    102.0        92.0
# 21  06/01/2013  GoalsScored    NaN       80      NaN         NaN

# %%
groupedstatsdf
# Out:
#                      Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 08/01/2012  MatchesPlayed   20.0       20     10.0        10.0
# 09/01/2012  MatchesPlayed   38.0       39     50.0        44.0
# 10/01/2012  MatchesPlayed   31.0       31     39.0        27.0
# 11/01/2012  MatchesPlayed   50.0       41     42.0        46.0
# 12/01/2012  MatchesPlayed   59.0       39     39.0        26.0
# 01/01/2013  MatchesPlayed   42.0       40     40.0        18.0
# 02/01/2013  MatchesPlayed   30.0       40     40.0        36.0
# 03/01/2013  MatchesPlayed   35.0       38     39.0        36.0
# 04/01/2013  MatchesPlayed   42.0       42     41.0        36.0
# 05/01/2013  MatchesPlayed   33.0       40     40.0        27.0
# 06/02/2013  MatchesPlayed    NaN       10      NaN         NaN
# 08/01/2012    GoalsScored   57.0       60     21.0        23.0
# 09/01/2012    GoalsScored  111.0      112    133.0       135.0
# 10/01/2012    GoalsScored   95.0       88     97.0        77.0
# ...

# %%
#With no specific column name mentioned, groupBy function takes index
groupedByMonth = groupedstatsdf.groupby(lambda Month: Month.split('/')[2])

# %%
for name,group in groupedByMonth:
    print (name, group)
# Out:
# 2012                      Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 08/01/2012  MatchesPlayed   20.0       20     10.0        10.0
# 09/01/2012  MatchesPlayed   38.0       39     50.0        44.0
# 10/01/2012  MatchesPlayed   31.0       31     39.0        27.0
# 11/01/2012  MatchesPlayed   50.0       41     42.0        46.0
# 12/01/2012  MatchesPlayed   59.0       39     39.0        26.0
# 08/01/2012    GoalsScored   57.0       60     21.0        23.0
# 09/01/2012    GoalsScored  111.0      112    133.0       135.0
# 10/01/2012    GoalsScored   95.0       88     97.0        77.0
# 11/01/2012    GoalsScored  121.0      116    120.0       137.0
# 12/01/2012    GoalsScored  183.0      109    125.0        72.0
# 2013                      Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 01/01/2013  MatchesPlayed   42.0       40     40.0        18.0
# 02/01/2013  MatchesPlayed   30.0       40     40.0        36.0
# ...

# %%
import pandas as pd
goal_data = pd.read_csv('goal_stats_euro_leagues_2012-13.csv')

# %%
goal_data.head()
# Out:
#         Month           Stat   EPL  La Liga  Serie A  Bundesliga
# 0  08/01/2012  MatchesPlayed  20.0       20     10.0        10.0
# 1  09/01/2012  MatchesPlayed  38.0       39     50.0        44.0
# 2  10/01/2012  MatchesPlayed  31.0       31     39.0        27.0
# 3  11/01/2012  MatchesPlayed  50.0       41     42.0        46.0
# 4  12/01/2012  MatchesPlayed  59.0       39     39.0        26.0

# %%
goal_data.set_index(['Month'],inplace=True)

# %%
goalsScoredDF = goal_data.ix[goal_data['Stat']=='GoalsScored']

# %%
goalsScoredDF.head()
# Out:
#                    Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 08/01/2012  GoalsScored   57.0       60     21.0        23.0
# 09/01/2012  GoalsScored  111.0      112    133.0       135.0
# 10/01/2012  GoalsScored   95.0       88     97.0        77.0
# 11/01/2012  GoalsScored  121.0      116    120.0       137.0
# 12/01/2012  GoalsScored  183.0      109    125.0        72.0

# %%
goalsScoredDF = goalsScoredDF.iloc[:,1:]

# %%
goalsScored_grp = goalsScoredDF.groupby(lambda Month: Month.split('/')[2])

# %%
goalsScored_grp.mean()
# Out:
#         EPL  La Liga  Serie A  Bundesliga
# 2012  113.4       97     99.2        88.8
# 2013   99.2      108    101.4        90.8

# %%
goalsScored_grp.count()
# Out:
#       EPL  La Liga  Serie A  Bundesliga
# 2012    5        5        5           5
# 2013    5        6        5           5

# %%
for name,group in goalsScored_grp:
    print (name, group)
# Out:
# 2012               EPL  La Liga  Serie A  Bundesliga
# Month
# 08/01/2012   57.0       60     21.0        23.0
# 09/01/2012  111.0      112    133.0       135.0
# 10/01/2012   95.0       88     97.0        77.0
# 11/01/2012  121.0      116    120.0       137.0
# 12/01/2012  183.0      109    125.0        72.0
# 2013               EPL  La Liga  Serie A  Bundesliga
# Month
# 01/01/2013  117.0      121    104.0        51.0
# 02/01/2013   87.0      110    100.0       101.0
# 03/01/2013   91.0      101     99.0       106.0
# 04/01/2013  105.0      127    102.0       104.0
# 05/01/2013   96.0      109    102.0        92.0
# 06/01/2013    NaN       80      NaN         NaN

# %%
fill_func = lambda x: x.fillna(x.mean())

# %%
trans = goalsScored_grp.transform(fill_func)

# %%
trans
# Out:
#               EPL  La Liga  Serie A  Bundesliga
# Month
# 08/01/2012   57.0       60     21.0        23.0
# 09/01/2012  111.0      112    133.0       135.0
# 10/01/2012   95.0       88     97.0        77.0
# 11/01/2012  121.0      116    120.0       137.0
# 12/01/2012  183.0      109    125.0        72.0
# 01/01/2013  117.0      121    104.0        51.0
# 02/01/2013   87.0      110    100.0       101.0
# 03/01/2013   91.0      101     99.0       106.0
# 04/01/2013  105.0      127    102.0       104.0
# 05/01/2013   96.0      109    102.0        92.0
# 06/01/2013   99.2       80    101.4        90.8

# %% [markdown]
# ### Filtering

# %%
import numpy as np
# Out:
# Empty DataFrame
# Columns: [Stat, EPL, La Liga, Serie A, Bundesliga]
# Index: []

# %%
help(trans.filter)
# Out:
# Help on method filter in module pandas.core.generic:
#
# filter(items=None, like=None, regex=None, axis=None) method of pandas.core.frame.DataFrame instance
#     Subset rows or columns of dataframe according to labels in
#     the specified index.
#
#     Note that this routine does not filter a dataframe on its
#     contents. The filter is applied to the labels of the index.
#
#     Parameters
#     ----------
#     items : list-like
#         List of info axis to restrict to (must not all be present)
#     like : string
#         Keep info axis where "arg in col == True"
#     regex : string (regular expression)
#         Keep info axis with re.search(regex, col) == True
#     axis : int or string axis name
#         The axis to filter on.  By default this is the info axis,
#         'index' for Series, 'columns' for DataFrame
#
#     Returns
#     -------
#     same type as input object
#
#     Examples
#     --------
#     >>> df
#     one  two  three
# ...

# %%
trans.filter(regex='^E')
# Out:
#               EPL
# Month
# 08/01/2012   57.0
# 09/01/2012  111.0
# 10/01/2012   95.0
# 11/01/2012  121.0
# 12/01/2012  183.0
# 01/01/2013  117.0
# 02/01/2013   87.0
# 03/01/2013   91.0
# 04/01/2013  105.0
# 05/01/2013   96.0
# 06/01/2013   99.2

# %%
trans.filter(like='2013',axis=0)
# Out:
#               EPL  La Liga  Serie A  Bundesliga
# Month
# 01/01/2013  117.0      121    104.0        51.0
# 02/01/2013   87.0      110    100.0       101.0
# 03/01/2013   91.0      101     99.0       106.0
# 04/01/2013  105.0      127    102.0       104.0
# 05/01/2013   96.0      109    102.0        92.0
# 06/01/2013   99.2       80    101.4        90.8

# %% [markdown]
# ### Merging & Joining
# * concat
# * append

# %%
A = trans.ix[:4, ['EPL']]

# %%
B = trans.ix[:4, ['Serie A']]

# %%
B
# Out:
#             Serie A
# Month
# 08/01/2012     21.0
# 09/01/2012    133.0
# 10/01/2012     97.0
# 11/01/2012    120.0

# %%
pd.concat([A,B],axis=1)
# Out:
#               EPL  Serie A
# Month
# 08/01/2012   57.0     21.0
# 09/01/2012  111.0    133.0
# 10/01/2012   95.0     97.0
# 11/01/2012  121.0    120.0
