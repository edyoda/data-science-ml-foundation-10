# %%
import pandas as pd

# %%
pd.read_csv('training_2016_sample100.csv')
# Out:
#        Unnamed: 0    parcelid  airconditioningtypeid  \
# 0          700585  10799625.0                    1.0
# 1          213498  11925276.0                    NaN
# 2          222086  14617906.0                    NaN
# 3          351492  12933620.0                    1.0
# 4           61559  10930378.0                    1.0
# 5           77842  11430082.0                    NaN
# 6          948273  14105849.0                    NaN
# 7          355782  14630242.0                    NaN
# 8          519052  14746749.0                    NaN
# 9         1017098  12057767.0                    1.0
# 10         209190  17300012.0                    NaN
# 11         814394  14071865.0                    NaN
# 12         383060  14088163.0                    NaN
# 13         843098  13839974.0                    NaN
# 14        1020937  13005206.0                    NaN
# 15        1032553  12228773.0                    NaN
# 16         844820  14265047.0                    NaN
# ...
