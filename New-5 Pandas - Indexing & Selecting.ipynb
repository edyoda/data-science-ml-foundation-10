# %%
#Regular dictionary within dictionary
SpotCrudePrices_2013_Data={
    'U.K. Brent' : {'2013-Q1':112.9, '2013-Q2':103.0, '2013-Q3':110.1, '2013-Q4':109.4},
    
    'Dubai':{'2013-Q1':108.1, '2013-Q2':100.8, '2013-Q3':106.1,'2013-Q4':106.7},
    
    'West Texas Intermediate':{'2013-Q1':94.4, '2013-Q2':94.2, '2013-Q3':105.8,'2013-Q4':97.4}
}

# %%
import pandas as pd

# %%
#Create dataframe from dict of dict
dubaiPrices = pd.DataFrame.from_dict(SpotCrudePrices_2013_Data)
dubaiPrices
# Out:
#          Dubai  U.K. Brent  West Texas Intermediate
# 2013-Q1  108.1       112.9                     94.4
# 2013-Q2  100.8       103.0                     94.2
# 2013-Q3  106.1       110.1                    105.8
# 2013-Q4  106.7       109.4                     97.4

# %%
#directly passing as a dictionary
pd.DataFrame(SpotCrudePrices_2013_Data)
# Out:
#          Dubai  U.K. Brent  West Texas Intermediate
# 2013-Q1  108.1       112.9                     94.4
# 2013-Q2  100.8       103.0                     94.2
# 2013-Q3  106.1       110.1                    105.8
# 2013-Q4  106.7       109.4                     97.4

# %%
SpotCrudePrices_2013_Data
# Out:
# {'Dubai': {'2013-Q1': 108.1,
#   '2013-Q2': 100.8,
#   '2013-Q3': 106.1,
#   '2013-Q4': 106.7},
#  'U.K. Brent': {'2013-Q1': 112.9,
#   '2013-Q2': 103.0,
#   '2013-Q3': 110.1,
#   '2013-Q4': 109.4},
#  'West Texas Intermediate': {'2013-Q1': 94.4,
#   '2013-Q2': 94.2,
#   '2013-Q3': 105.8,
#   '2013-Q4': 97.4}}

# %%
dubaiPrices[['Dubai']]
# Out:
#          Dubai
# 2013-Q1  108.1
# 2013-Q2  100.8
# 2013-Q3  106.1
# 2013-Q4  106.7

# %%
dubaiPrices.Dubai
# Out:
# 2013-Q1    108.1
# 2013-Q2    100.8
# 2013-Q3    106.1
# 2013-Q4    106.7
# Name: Dubai, dtype: float64

# %%
dubaiPrices.columns
# Out:
# Index(['Dubai', 'U.K. Brent', 'West Texas Intermediate'], dtype='object')

# %%
dubaiPrices.index
# Out:
# Index(['2013-Q1', '2013-Q2', '2013-Q3', '2013-Q4'], dtype='object')

# %%
dubaiPrices.mean()
# Out:
# Dubai                      105.425
# U.K. Brent                 108.850
# West Texas Intermediate     97.950
# dtype: float64

# %%
#
dubaiPrices.describe()
# Out:
#             Dubai  U.K. Brent  West Texas Intermediate
# count    4.000000    4.000000                 4.000000
# mean   105.425000  108.850000                97.950000
# std      3.195179    4.182902                 5.434151
# min    100.800000  103.000000                94.200000
# 25%    104.775000  107.800000                94.350000
# 50%    106.400000  109.750000                95.900000
# 75%    107.050000  110.800000                99.500000
# max    108.100000  112.900000               105.800000

# %%
dubaiPrices
# Out:
#          Dubai  U.K. Brent  West Texas Intermediate
# 2013-Q1  108.1       112.9                     94.4
# 2013-Q2  100.8       103.0                     94.2
# 2013-Q3  106.1       110.1                    105.8
# 2013-Q4  106.7       109.4                     97.4

# %%
dubaiPrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 2013-Q1 to 2013-Q4
# Data columns (total 3 columns):
# Dubai                      4 non-null float64
# U.K. Brent                 4 non-null float64
# West Texas Intermediate    4 non-null float64
# dtypes: float64(3)
# memory usage: 288.0+ bytes

# %%
#Changing col names
dubaiPrices.columns = ['Dubai','Brent','Texas']

# %%
dubaiPrices
# Out:
#          Dubai  Brent  Texas
# 2013-Q1  108.1  112.9   94.4
# 2013-Q2  100.8  103.0   94.2
# 2013-Q3  106.1  110.1  105.8
# 2013-Q4  106.7  109.4   97.4

# %%
dubaiPrices.rename(columns={'Dubai':'Bangalore'})
# Out:
#          Bangalore  Brent  Texas
# 2013-Q1      108.1  112.9   94.4
# 2013-Q2      100.8  103.0   94.2
# 2013-Q3      106.1  110.1  105.8
# 2013-Q4      106.7  109.4   97.4

# %%
pd.read_csv

# %%
#Get data by column index, 1 & 2 are col index
dubaiPrices[[1,2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-7fbbb5ca93ff> in <module>()
#       1 #Get data by column index, 1 & 2 are col index
# ----> 2 dubaiPrices[[1,2]]
#
# ~\Anaconda3-N\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~\Anaconda3-N\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
# ...

# %%
import numpy as np
#Use arange to access elements
dubaiPrices
# Out:
#          Dubai  Brent  Texas
# 2013-Q1  108.1  112.9   94.4
# 2013-Q2  100.8  103.0   94.2
# 2013-Q3  106.1  110.1  105.8
# 2013-Q4  106.7  109.4   97.4

# %% [markdown]
# #### Use slicing to extract rows

# %%
dubaiPrices[2:3]
# Out:
#          Dubai  Brent  Texas
# 2013-Q3  106.1  110.1  105.8

# %%
dubaiPrices[0:3:2]
# Out:
#          Dubai  Brent  Texas
# 2013-Q1  108.1  112.9   94.4
# 2013-Q3  106.1  110.1  105.8

# %%
dubaiPrices[2:]
# Out:
#          Dubai  Brent  Texas
# 2013-Q3  106.1  110.1  105.8
# 2013-Q4  106.7  109.4   97.4

# %%
dubaiPrices[::-1]
# Out:
#          Dubai  Brent  Texas
# 2013-Q4  106.7  109.4   97.4
# 2013-Q3  106.1  110.1  105.8
# 2013-Q2  100.8  103.0   94.2
# 2013-Q1  108.1  112.9   94.4

# %%
dubaiPrices[np.arange(2,3)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-c7c32255c94a> in <module>()
# ----> 1 dubaiPrices[np.arange(2,3)]
#
# ~\Anaconda3-N\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~\Anaconda3-N\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ...

# %%
# Dictionary of lists
NYC_SnowAvgsData={
    'Months' :['January','February','March', 'April', 'November', 'December'],
    'Avg SnowDays' : [4.0,2.7,1.7,0.2,0.2,2.3],
    'Avg Precip. (cm)' : [17.8,22.4,9.1,1.5,0.8,12.2],
    'Avg Low Temp. (F)' : [27,29,35,45,42,32] 
}

# %%
NYC_SnowAvgs_index=pd.DataFrame(NYC_SnowAvgsData,
                                
        index= NYC_SnowAvgsData['Months'], 
        columns = ['Avg SnowDays','Avg Precip. (cm)','Avg Low Temp. (F)']
)

# %%
NYC_SnowAvgs_index
# Out:
#           Avg SnowDays  Avg Precip. (cm)  Avg Low Temp. (F)
# January            4.0              17.8                 27
# February           2.7              22.4                 29
# March              1.7               9.1                 35
# April              0.2               1.5                 45
# November           0.2               0.8                 42
# December           2.3              12.2                 32

# %%
NYC_SnowAvgs=pd.DataFrame(NYC_SnowAvgsData,  
        columns = ['Months','Avg SnowDays','Avg Precip. (cm)','Avg Low Temp. (F)'])

# %%
NYC_SnowAvgs

# %% [markdown]
# ### loc iloc ix
# * This gives you access to a specific data

# %%
dubaiPrices

# %%
NYC_SnowAvgs_index

# %%
#This gets sliced data
dubaiPrices[2:]

# %%
NYC_SnowAvgs_index.loc['January']['Avg SnowDays']
# Out:
# 4.0

# %%
NYC_SnowAvgs_index.loc[['January','April']]
# Out:
#          Avg SnowDays  Avg Precip. (cm)  Avg Low Temp. (F)
# January           4.0              17.8                 27
# April             0.2               1.5                 45

# %%
NYC_SnowAvgs_index[['Avg SnowDays','Avg Precip. (cm)']]

# %%
NYC_SnowAvgs_index.loc['January':'April']
# Out:
#           Avg SnowDays  Avg Precip. (cm)  Avg Low Temp. (F)
# January            4.0              17.8                 27
# February           2.7              22.4                 29
# March              1.7               9.1                 35
# April              0.2               1.5                 45

# %%
#NYC_SnowAvgs_index.loc[1:4]
#Fails

# %%
NYC_SnowAvgs_index[1:4]

# %%
NYC_SnowAvgs_index.iloc[1:4][['Avg SnowDays','Avg Low Temp. (F)']]
# Out:
#           Avg SnowDays  Avg Low Temp. (F)
# February           2.7                 29
# March              1.7                 35
# April              0.2                 45

# %%
#First element is row, next one is column
NYC_SnowAvgs_index.iloc[1:3,1:2]
# Out:
#           Avg Precip. (cm)
# February              22.4
# March                  9.1

# %%
NYC_SnowAvgs_index
# Out:
#           Avg SnowDays  Avg Precip. (cm)  Avg Low Temp. (F)
# January            4.0              17.8                 27
# February           2.7              22.4                 29
# March              1.7               9.1                 35
# April              0.2               1.5                 45
# November           0.2               0.8                 42
# December           2.3              12.2                 32

# %%
#Same index name being used
SnowAvgsData={
    'Months' :['January','February','April', 'April', 'November', 'December'],
    'Avg SnowDays' : [4.0,2.7,1.7,0.2,0.2,2.3],
    'Avg Precip. (cm)' : [17.8,22.4,9.1,1.5,0.8,12.2],
    'Avg Low Temp. (F)' : [27,29,35,45,42,32] 
}

# %%
#col names should be subset of keys of dictionary
SnowAvgs_index=pd.DataFrame(SnowAvgsData,  
        index= SnowAvgsData['Months'], 
        columns = ['Avg SnowDays','Avg Precip. (cm)','Avg Low Temp. (F)']
)

# %%
SnowAvgs_index
# Out:
#           Avg SnowDays  Avg Precip. (cm)  Avg Low Temp. (F)
# January            4.0              17.8                 27
# February           2.7              22.4                 29
# April              1.7               9.1                 35
# April              0.2               1.5                 45
# November           0.2               0.8                 42
# December           2.3              12.2                 32

# %%
SnowAvgs_index.loc['April']
# Out:
#        Avg SnowDays  Avg Precip. (cm)  Avg Low Temp. (F)
# April           1.7               9.1                 35
# April           0.2               1.5                 45

# %%
NYC_SnowAvgsData={
    'Months' : ['January','February','March', 'April', 'November', 'December'],
    'Avg SnowDays' : [4.0,2.7,1.7,0.2,0.2,2.3],
    'Avg Precip. (cm)' : [17.8,22.4,9.1,1.5,0.8,12.2],
    'Avg Low Temp. (F)' : [27,29,35,45,42,32] 
}

# %%
NYC_SnowAvgs=pd.DataFrame(NYC_SnowAvgsData,  
        index= NYC_SnowAvgsData['Months'], 
        columns = ['Months','Avg SnowDays','Avg Precip. (cm)','Avg Low Temp. (F)'])

# %%
NYC_SnowAvgs.loc[(NYC_SnowAvgs['Avg SnowDays']>1) & (NYC_SnowAvgs['Avg SnowDays']<2),:]
# Out:
#       Months  Avg SnowDays  Avg Precip. (cm)  Avg Low Temp. (F)
# March  March           1.7               9.1                 35

# %%
NYC_SnowAvgs.loc[(NYC_SnowAvgs['Avg SnowDays']>1) & (NYC_SnowAvgs['Avg SnowDays']<2),['Avg SnowDays','Avg Precip. (cm)']]
# Out:
#        Avg SnowDays  Avg Precip. (cm)
# March           1.7               9.1

# %%
#Selecting using boolean array
NYC_SnowAvgs.loc[(NYC_SnowAvgs['Avg SnowDays']>1) & (NYC_SnowAvgs['Avg SnowDays']<2),:]
# Out:
#       Months  Avg SnowDays  Avg Precip. (cm)  Avg Low Temp. (F)
# March  March           1.7               9.1                 35

# %%
#Returns boolean array
NYC_SnowAvgs[NYC_SnowAvgs['Avg SnowDays']<1]
# Out:
#             Months  Avg SnowDays  Avg Precip. (cm)  Avg Low Temp. (F)
# April        April           0.2               1.5                 45
# November  November           0.2               0.8                 42

# %%
dubaiPrices
dubaiPrices.loc['2013-Q1']>110
# Out:
# Dubai    False
# Brent     True
# Texas    False
# Name: 2013-Q1, dtype: bool

# %%
dubaiPrices
# Out:
#          Dubai  Brent  Texas
# 2013-Q1  108.1  112.9   94.4
# 2013-Q2  100.8  103.0   94.2
# 2013-Q3  106.1  110.1  105.8
# 2013-Q4  106.7  109.4   97.4

# %%
dubaiPrices.loc[:,dubaiPrices.loc['2013-Q1']>94]
# Out:
#          Dubai  Brent  Texas
# 2013-Q1  108.1  112.9   94.4
# 2013-Q2  100.8  103.0   94.2
# 2013-Q3  106.1  110.1  105.8
# 2013-Q4  106.7  109.4   97.4

# %%
dubaiPrices
# Out:
#          Dubai  Brent  Texas
# 2013-Q1  108.1  112.9   94.4
# 2013-Q2  100.8  103.0   94.2
# 2013-Q3  106.1  110.1  105.8
# 2013-Q4  106.7  109.4   97.4

# %%
dubaiPrices.loc['2013-Q1']>109
# Out:
# Dubai    False
# Brent     True
# Texas    False
# Name: 2013-Q1, dtype: bool

# %% [markdown]
# ### iloc - Integer Oriented Indexing

# %%
dubaiPrices
# Out:
#          Dubai  Brent  Texas
# 2013-Q1  108.1  112.9   94.4
# 2013-Q2  100.8  103.0   94.2
# 2013-Q3  106.1  110.1  105.8
# 2013-Q4  106.7  109.4   97.4

# %%
dubaiPrices.iloc[1:,2:]
# Out:
#          Texas
# 2013-Q2   94.2
# 2013-Q3  105.8
# 2013-Q4   97.4

# %%
#Accessing by index id
dubaiPrices.iat[3,0]
# Out:
# 106.7

# %%
#Accessing by value
dubaiPrices.at['2013-Q4','Dubai']
# Out:
# 106.7

# %% [markdown]
# ### Thumb Rules
# * at -> Access a specific value given index & col
#   dubaiPrices.at['2013-Q4','Dubai']
#
# * iat -> Access a specific value given index id & col id
# * loc -> Access row by index value
#   NYC_SnowAvgs_index.loc['January']['Avg SnowDays']
#
# * iloc -> Access row by index id

# %%
import pandas as pd

# %%
stockDF = pd.read_csv(r'D:\data-science-ml-foundation-10\Stock.csv')

# %%
stockDF
# Out:
#   TradingDate   Nasdaq  S&P 500  Russell 2000
# 0  2014/01/30  4123.13  1794.19       1139.36
# 1  2014/01/31  4103.88  1782.59       1130.88
# 2  2014/02/03  3996.96  1741.89       1094.58
# 3  2014/02/04  4031.52  1755.20       1102.84
# 4  2014/02/05  4011.55  1751.64       1093.59
# 5  2014/02/06  4057.12  1773.43       1103.93

# %%
stockIndexDF = stockDF.set_index('TradingDate')

# %%
stockIndexDF
# Out:
#               Nasdaq  S&P 500  Russell 2000
# TradingDate
# 2014/01/30   4123.13  1794.19       1139.36
# 2014/01/31   4103.88  1782.59       1130.88
# 2014/02/03   3996.96  1741.89       1094.58
# 2014/02/04   4031.52  1755.20       1102.84
# 2014/02/05   4011.55  1751.64       1093.59
# 2014/02/06   4057.12  1773.43       1103.93

# %%
###ix - loc first & iloc after that
stockIndexDF.ix['2014/02/03']
# Out:
# Nasdaq          3996.96
# S&P 500         1741.89
# Russell 2000    1094.58
# Name: 2014/02/03, dtype: float64

# %%
stockIndexDF.ix[1]
# Out:
# Nasdaq          4103.88
# S&P 500         1782.59
# Russell 2000    1130.88
# Name: 2014/01/31, dtype: float64

# %%
stockDF.ix[1]
# Out:
# TradingDate     2014/01/31
# Nasdaq             4103.88
# S&P 500            1782.59
# Russell 2000       1130.88
# Name: 1, dtype: object

# %% [markdown]
# ### MultiIndexing

# %%
stock_data = pd.read_csv('MoreStock.csv')

# %%
stock_data
# Out:
#    TradingDate PriceType   Nasdaq  S&P 500  Russell 2000
# 0   2014/02/21      open  4282.17  1841.07       1166.25
# 1   2014/02/21     close  4263.41  1836.25       1164.63
# 2   2014/02/21      high  4284.85  1846.13       1168.43
# 3   2014/02/24      open  4273.32  1836.78       1166.74
# 4   2014/02/24     close  4292.97  1847.61       1174.55
# 5   2014/02/24      high  4311.13  1858.71       1180.29
# 6   2014/02/25      open  4298.48  1847.66       1176.00
# 7   2014/02/25     close  4287.59  1845.12       1173.95
# 8   2014/02/25      high  4307.51  1852.91       1179.43
# 9   2014/02/26      open  4300.45  1845.79       1176.11
# 10  2014/02/26     close  4292.06  1845.16       1181.72
# 11  2014/02/26      high  4316.82  1852.65       1188.06
# 12  2014/02/27      open  4291.47  1844.90       1179.28
# 13  2014/02/27     close  4318.93  1854.29       1187.94
# 14  2014/02/27      high  4322.46  1854.53       1187.94
# ...

# %%
stock_Index_data = stock_data.set_index(['TradingDate','PriceType'])

# %%
stock_Index_data.head()
# Out:
#                         Nasdaq  S&P 500  Russell 2000
# TradingDate PriceType
# 2014/02/21  open       4282.17  1841.07       1166.25
#             close      4263.41  1836.25       1164.63
#             high       4284.85  1846.13       1168.43
# 2014/02/24  open       4273.32  1836.78       1166.74
#             close      4292.97  1847.61       1174.55

# %%
stock_Index_data.loc['2014/02/21']
# Out:
#             Nasdaq  S&P 500  Russell 2000
# PriceType
# open       4282.17  1841.07       1166.25
# close      4263.41  1836.25       1164.63
# high       4284.85  1846.13       1168.43

# %%
stock_Index_data.index
# Out:
# MultiIndex(levels=[['2014/02/21', '2014/02/24', '2014/02/25', '2014/02/26', '2014/02/27', '2014/02/28'], ['close', 'high', 'open']],
#            labels=[[0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5], [2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1]],
#            names=['TradingDate', 'PriceType'])

# %%
stock_Index_data.loc['2014/02/21','open']
# Out:
# Nasdaq          4282.17
# S&P 500         1841.07
# Russell 2000    1166.25
# Name: (2014/02/21, open), dtype: float64

# %%
stock_Index_data.loc['2014/02/21':'2014/02/25']
# Out:
#                         Nasdaq  S&P 500  Russell 2000
# TradingDate PriceType
# 2014/02/21  open       4282.17  1841.07       1166.25
#             close      4263.41  1836.25       1164.63
#             high       4284.85  1846.13       1168.43
# 2014/02/24  open       4273.32  1836.78       1166.74
#             close      4292.97  1847.61       1174.55
#             high       4311.13  1858.71       1180.29
# 2014/02/25  open       4298.48  1847.66       1176.00
#             close      4287.59  1845.12       1173.95
#             high       4307.51  1852.91       1179.43

# %%
births = pd.read_csv('births.csv')

# %%
births.describe()
# Out:
#                year         month         births
# count  15547.000000  15547.000000   15547.000000
# mean    1979.037435      6.515919    9762.293561
# std        6.728340      3.449632   28552.465810
# min     1969.000000      1.000000       1.000000
# 25%     1974.000000      4.000000    4358.000000
# 50%     1979.000000      7.000000    4814.000000
# 75%     1984.000000     10.000000    5289.500000
# max     2008.000000     12.000000  199622.000000

# %%
births.columns
# Out:
# Index(['year', 'month', 'day', 'gender', 'births'], dtype='object')

# %%
birthidx = births.set_index(['year','month'])

# %%
birthidx
# Out:
#              day gender  births
# year month
# 1969 1         1      F    4046
#      1         1      M    4440
#      1         2      F    4454
#      1         2      M    4548
#      1         3      F    4548
#      1         3      M    4994
#      1         4      F    4440
#      1         4      M    4520
#      1         5      F    4192
#      1         5      M    4198
#      1         6      F    4710
#      1         6      M    4850
#      1         7      F    4646
#      1         7      M    5092
#      1         8      F    4800
#      1         8      M    4934
#      1         9      F    4592
#      1         9      M    4842
#      1        10      F    4852
#      1        10      M    5190
#      1        11      F    4580
#      1        11      M    4598
#      1        12      F    4126
#      1        12      M    4324
#      1        13      F    4758
#      1        13      M    5076
#      1        14      F    5070
#      1        14      M    5296
# ...

# %%
birthidx.loc[1969,1]
# Out:
#            day gender  births
# year month
# 1969 1       1      F    4046
#      1       1      M    4440
#      1       2      F    4454
#      1       2      M    4548
#      1       3      F    4548
#      1       3      M    4994
#      1       4      F    4440
#      1       4      M    4520
#      1       5      F    4192
#      1       5      M    4198
#      1       6      F    4710
#      1       6      M    4850
#      1       7      F    4646
#      1       7      M    5092
#      1       8      F    4800
#      1       8      M    4934
#      1       9      F    4592
#      1       9      M    4842
#      1      10      F    4852
#      1      10      M    5190
#      1      11      F    4580
#      1      11      M    4598
#      1      12      F    4126
#      1      12      M    4324
#      1      13      F    4758
#      1      13      M    5076
#      1      14      F    5070
#      1      14      M    5296
#      1      15      F    4798
# ...

# %%
birthidx[birthidx.gender == 'F']
# Out:
#              day gender  births
# year month
# 1969 1         1      F    4046
#      1         2      F    4454
#      1         3      F    4548
#      1         4      F    4440
#      1         5      F    4192
#      1         6      F    4710
#      1         7      F    4646
#      1         8      F    4800
#      1         9      F    4592
#      1        10      F    4852
#      1        11      F    4580
#      1        12      F    4126
#      1        13      F    4758
#      1        14      F    5070
#      1        15      F    4798
#      1        16      F    4790
#      1        17      F    4944
#      1        18      F    4670
#      1        19      F    4170
#      1        20      F    4884
#      1        21      F    5042
#      1        22      F    4796
#      1        23      F    4794
#      1        24      F    4752
#      1        25      F    4348
#      1        26      F    4230
#      1        27      F    4864
#      1        28      F    4860
# ...

# %%
len(birthidx[birthidx.gender == 'M'])
# Out:
# 7771

# %%
birthidx
# Out:
#              day gender  births
# year month
# 1969 1         1      F    4046
#      1         1      M    4440
#      1         2      F    4454
#      1         2      M    4548
#      1         3      F    4548
#      1         3      M    4994
#      1         4      F    4440
#      1         4      M    4520
#      1         5      F    4192
#      1         5      M    4198
#      1         6      F    4710
#      1         6      M    4850
#      1         7      F    4646
#      1         7      M    5092
#      1         8      F    4800
#      1         8      M    4934
#      1         9      F    4592
#      1         9      M    4842
#      1        10      F    4852
#      1        10      M    5190
#      1        11      F    4580
#      1        11      M    4598
#      1        12      F    4126
#      1        12      M    4324
#      1        13      F    4758
#      1        13      M    5076
#      1        14      F    5070
#      1        14      M    5296
# ...

# %%
df = pd.read_csv('california_cities.csv',index_col=0)

# %%
df[df['area_water_percent'].isnull()]
# Out:
#              city       latd       longd  elevation_m  elevation_ft  \
# 143     FortBragg  39.445833 -123.805278         26.0          85.0
# 197  JurupaValley  33.999444 -117.475278          NaN           NaN
# 237      LosAltos  37.368056 -122.097500          NaN         157.0
# 393   SantaMonica  34.021944 -118.481389          NaN         105.0
# 443     UnionCity  37.586944 -122.025833          NaN           NaN
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 143              7273             2.800            2.700               NaN
# 197             97496            43.500           43.300             0.200
# 237             28976             6.487            6.487             0.000
# 393             89736             8.416            8.415             0.001
# 443             72155            19.000           19.000             0.000
#
#      area_total_km2  area_land_km2  area_water_km2  area_water_percent
# ...

# %%
df[df['area_water_percent'].notnull()]
# Out:
#      Unnamed: 0             city       latd       longd  elevation_m  \
# 0             0         Adelanto  34.576111 -117.432778        875.0
# 1             1      AgouraHills  34.153333 -118.761667        281.0
# 2             2          Alameda  37.756111 -122.274444          NaN
# 3             3           Albany  37.886944 -122.297778          NaN
# 4             4         Alhambra  34.081944 -118.135000        150.0
# 5             5       AlisoViejo  33.575000 -117.725556        127.0
# 6             6          Alturas  41.487222 -120.542500       1332.0
# 7             7       AmadorCity  38.419444 -120.824167        280.0
# 8             8   AmericanCanyon  38.168056 -122.252500         14.0
# 9             9          Anaheim  33.836111 -117.889722         48.0
# 10           10         Anderson  40.452222 -122.296667        132.0
# 11           11       AngelsCamp  38.068333 -120.539722        420.0
# 12           12          Antioch  38.005000 -121.805833         13.0
# ...

# %%
df.head()
# Out:
#           city       latd       longd  elevation_m  elevation_ft  \
# 0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2      Alameda  37.756111 -122.274444          NaN          33.0
# 3       Albany  37.886944 -122.297778          NaN          43.0
# 4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
#    area_total_km2  area_land_km2  area_water_km2  area_water_percent
# ...

# %%
df.iloc[1:5]
# Out:
#           city       latd       longd  elevation_m  elevation_ft  \
# 1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2      Alameda  37.756111 -122.274444          NaN          33.0
# 3       Albany  37.886944 -122.297778          NaN          43.0
# 4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
#    area_total_km2  area_land_km2  area_water_km2  area_water_percent
# 1          20.260         20.184           0.076                0.37
# 2          59.465         27.482          31.983               53.79
# ...

# %%
df.set_index(['city'],inplace=True)

# %%
df.loc['Albany':'Anaheim']
# Out:
#                      latd       longd  elevation_m  elevation_ft  \
# city
# Albany          37.886944 -122.297778          NaN          43.0
# Alhambra        34.081944 -118.135000        150.0         492.0
# AlisoViejo      33.575000 -117.725556        127.0         417.0
# Alturas         41.487222 -120.542500       1332.0        4370.0
# AmadorCity      38.419444 -120.824167        280.0         919.0
# AmericanCanyon  38.168056 -122.252500         14.0          46.0
# Anaheim         33.836111 -117.889722         48.0         157.0
#
#                 population_total  area_total_sq_mi  area_land_sq_mi  \
# city
# Albany                     18969             5.465            1.788
# Alhambra                   83089             7.632            7.631
# AlisoViejo                 47823             7.472            7.472
# Alturas                     2827             2.449            2.435
# AmadorCity                   185             0.314            0.314
# ...
