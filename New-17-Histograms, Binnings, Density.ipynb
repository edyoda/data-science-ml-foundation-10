# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %%
data = np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([   2.,   19.,  102.,  216.,  298.,  233.,  105.,   18.,    6.,    1.]),
#  array([-3.37224626, -2.61707335, -1.86190045, -1.10672755, -0.35155465,
#          0.40361826,  1.15879116,  1.91396406,  2.66913697,  3.42430987,
#          4.17948277]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data, bins=30, alpha=0.5, color='red')
# Out:
# (array([   2.,    0.,    0.,    5.,    5.,    9.,   22.,   32.,   48.,
#           63.,   77.,   76.,   83.,  111.,  104.,  102.,   64.,   67.,
#           57.,   27.,   21.,    4.,   10.,    4.,    2.,    2.,    2.,
#            0.,    0.,    1.]),
#  array([-3.37224626, -3.12052196, -2.86879766, -2.61707335, -2.36534905,
#         -2.11362475, -1.86190045, -1.61017615, -1.35845185, -1.10672755,
#         -0.85500325, -0.60327895, -0.35155465, -0.09983034,  0.15189396,
#          0.40361826,  0.65534256,  0.90706686,  1.15879116,  1.41051546,
#          1.66223976,  1.91396406,  2.16568837,  2.41741267,  2.66913697,
#          2.92086127,  3.17258557,  3.42430987,  3.67603417,  3.92775847,
#          4.17948277]),
#  <a list of 30 Patch objects>)

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

# %%
plt.hist(x1,bins=30, alpha=0.3, color='red')
plt.hist(x2,bins=30, alpha=0.3, color='green')
plt.hist(x3,bins=30, alpha=0.3, color='blue')
# Out:
# (array([   1.,    0.,    2.,    3.,    3.,    6.,   19.,   24.,   37.,
#           51.,   80.,   80.,   83.,   74.,  109.,   84.,   93.,   65.,
#           61.,   41.,   28.,   23.,   19.,    8.,    2.,    2.,    0.,
#            0.,    1.,    1.]),
#  array([ -4.20681672,  -3.71073594,  -3.21465516,  -2.71857437,
#          -2.22249359,  -1.72641281,  -1.23033202,  -0.73425124,
#          -0.23817046,   0.25791033,   0.75399111,   1.25007189,
#           1.74615268,   2.24223346,   2.73831424,   3.23439503,
#           3.73047581,   4.22655659,   4.72263738,   5.21871816,
#           5.71479894,   6.21087973,   6.70696051,   7.20304129,
#           7.69912208,   8.19520286,   8.69128364,   9.18736443,
#           9.68344521,  10.17952599,  10.67560678]),
#  <a list of 30 Patch objects>)

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x,y,bins=30,cmap='Blues')
cb = plt.colorbar()
